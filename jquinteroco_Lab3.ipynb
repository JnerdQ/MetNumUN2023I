# %% [markdown]
# <a href="https://colab.research.google.com/github/JnerdQ/MetNumUN2023I/blob/main/jquinteroco_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Certificados Linkedin

# %% [markdown]
# ######https://www.linkedin.com/in/juli%C3%A1n-andr%C3%A9s-quintero-contreras-6b2006199/

# %% [markdown]
# ![certificados.png](data:image/png;base64,...)
